# %% [markdown]
# # ***Questions are presented sequentially, each followed directly by its corresponding answer.***

# %% [markdown]
# **Question 1: Basic Print**
# Write a Python program that prints the following text exactly:
#
# Welcome to Python Programming!
# I am learning the basics.

# %%
print(f"Welcome to Python Programming!\nI am learning the basics.")
# Out:
# Welcome to Python Programming!
# I am learning the basics.

# %% [markdown]
# **Question 2: Print with Variables**
# Create two variables:
# - name → your name
# - age → your age
#
# Print the output like this:
# My name is Tahmid and I am 25 years old.

# %%
name = "Eiamin Hassan Shanto"
age = 25
print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is Eiamin Hassan Shanto and I am 25 years old.

# %% [markdown]
# **Question 3: User Input**
# Take user input for:
# - Name
# - Favorite programming language
#
# Print a message:
# Hello \<name>, your favorite language is \<language>.

# %%
name = input("Enter your name:")
p_lang = input("Enter your favorite programming language:")

print(f"Hello {name}, your favorite language is {p_lang}.")
# Out:
# Enter your name:Eiamin Hassan Shanto
# Enter your favorite programming language:C++
# Hello Eiamin Hassan Shanto, your favorite language is C++.

# %% [markdown]
# **Question 4: Type Casting (String to Integer)**
# 1. Take two numbers from the user using input()
# 2. Convert them to integers
# 3. Print their sum
#
# Example output:
# The sum is: 30

# %%
n1 = input("Enter first number:")
n2 = input("Enter second number:")

# Converting to integers
n1 = int(n1)
n2 = int(n2)

sum = n1 + n2

print(f"The sum is: {sum}")
# Out:
# Enter first number:10
# Enter second number:20
# The sum is: 30

# %% [markdown]
# **Question 5: Simple Calculator**
# Take two numbers from the user and:
# - Convert them to integers
# - Print Addition
# - Print Subtraction
# - Print Multiplication
#
# Example:
# Addition: 20
# Subtraction: 10
# Multiplication: 75

# %%
n1 = input("Enter first number:")
n2 = input("Enter second number:")

# Converting to integers
n1 = int(n1)
n2 = int(n2)


add = n1 + n2
mul = n1 * n2

if n1 >= n2:
  sub = n1 - n2
else:
  sub = n2 - n1

print(f"Addition: {add}")
print(f"Subtraction: {sub}")
print(f"Multiplication: {mul}")
# Out:
# Enter first number:5
# Enter second number:15
# Addition: 20
# Subtraction: 10
# Multiplication: 75
